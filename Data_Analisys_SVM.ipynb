# %% [markdown]
# # SENTIMENT ANALYSIS

# %%
import pandas as pd 
import nltk# as nlkt
import re
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from bs4 import BeautifulSoup
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import joblib
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer

# %%
df = pd.read_csv('IMDB Dataset.csv', encoding = 'Latin-1')
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
print(len(df))
# Out:
# 50000

# %%
df['sentiment'] = df['sentiment'].map({'positive': 1, 'negative': 0})
df.head()
# Out:
#                                               review  sentiment
# 0  One of the other reviewers has mentioned that ...          1
# 1  A wonderful little production. <br /><br />The...          1
# 2  I thought this was a wonderful way to spend ti...          1
# 3  Basically there's a family where a little boy ...          0
# 4  Petter Mattei's "Love in the Time of Money" is...          1

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
stop_words = set(stopwords.words("english")) 
lemmatizer = WordNetLemmatizer()

# %%
#Removing the html strips
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

# %%
#Defining clean_text function
def clean_text(text):
    text = strip_html(text)
    text = re.sub(r'[^A-Za-z0-9]+',' ',text)
    text = text.lower()
    text = [lemmatizer.lemmatize(token) for token in text.split(" ")]
    text = [lemmatizer.lemmatize(token, "v") for token in text]
    text = [word for word in text if not word in stop_words]
    text = " ".join(text)
    return text

# %%
df['Processed_Reviews'] = df.review.apply(lambda x: clean_text(x))
# Out:
# /shared-libs/python3.9/py-core/lib/python3.9/site-packages/bs4/__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(

# %%
print(df['Processed_Reviews'][0])
print(df.head())
# Out:
# one reviewer ha mention watch 1 oz episode hook right exactly happen first thing strike oz wa brutality unflinching scene violence set right word go trust show faint hearted timid show pull punch regard drug sex violence hardcore classic use word call oz nickname give oswald maximum security state penitentary focus mainly emerald city experimental section prison cell glass front face inwards privacy high agenda em city home many aryan muslim gangsta latino christian italian irish scuffle death stare dodgy deal shady agreement never far away would say main appeal show due fact go show dare forget pretty picture paint mainstream audience forget charm forget romance oz mess around first episode ever saw strike nasty wa surreal say wa ready watch develop taste oz get accustom high level graphic violence violence injustice crook guard sell nickel inmate kill order get away well mannered middle class inmate turn prison bitch due lack street skill prison experience watch oz may become comfortable uncomfortable view thats get touch darker side
#                                               review  sentiment  \
# 0  One of the other reviewers has mentioned that ...          1
# 1  A wonderful little production. <br /><br />The...          1
# 2  I thought this was a wonderful way to spend ti...          1
# 3  Basically there's a family where a little boy ...          0
# 4  Petter Mattei's "Love in the Time of Money" is...          1
#
#                                    Processed_Reviews
# 0  one reviewer ha mention watch 1 oz episode hoo...
# 1  wonderful little production film technique una...
# 2  think wa wonderful way spend time hot summer w...
# 3  basically family little boy jake think zombie ...
# 4  petter mattei love time money visually stun fi...

# %% [markdown]
# ## SVM Model

# %%
x = df['Processed_Reviews']
y = df['sentiment']

#Training and splitting
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
#Vectorization and Bag of words method with default parameters
count_vect = CountVectorizer().fit(df['Processed_Reviews'].values.astype('U'))
bow_train = count_vect.transform(X_train.values.astype('U'))
bow_test = count_vect.transform(X_test.values.astype('U'))


#instantiate the model (using the default parameters)
SVM = SVC()

# %%
# fit the model with pre-processed data
SVM.fit(bow_train, y_train)

#perform classification and prediction on samples in tf_test
predicted_SVM = SVM.predict(bow_test)
print(classification_report(y_test, predicted_SVM))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87      5035
#            1       0.86      0.89      0.87      4965
#
#     accuracy                           0.87     10000
#    macro avg       0.87      0.87      0.87     10000
# weighted avg       0.87      0.87      0.87     10
with: {'SVM__C': 10, 'SVM__kernel': 'poly', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 3)}
# 0.567730 (0.011726) with: {'SVM__C': 10, 'SVM__kernel': 'poly', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 1)}
# 0.534924 (0.013142) with: {'SVM__C': 10, 'SVM__kernel': 'poly', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 2)}
# 0.526383 (0.007660) with: {'SVM__C': 10, 'SVM__kernel': 'poly', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 3)}
# 0.564853 (0.020228) with: {'SVM__C': 10, 'SVM__kernel': 'poly', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 1)}
# 0.537771 (0.017326) with: {'SVM__C': 10, 'SVM__kernel': 'poly', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 2)}
# 0.529240 (0.007938) with: {'SVM__C': 10, 'SVM__kernel': 'poly', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 3)}
# 0.590557 (0.012452) with: {'SVM__C': 10, 'SVM__kernel': 'poly', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 1)}
# 0.550598 (0.018485) with: {'SVM__C': 10, 'SVM__kernel': 'poly', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 2)}
# 0.534924 (0.014613) with: {'SVM__C': 10, 'SVM__kernel': 'poly', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 3)}
# 0.754711 (0.033918) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.1, 'vect__ngram_range': (1, 1)}
# 0.781763 (0.016939) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.1, 'vect__ngram_range': (1, 2)}
# 0.787467 (0.017450) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.1, 'vect__ngram_range': (1, 3)}
# 0.774650 (0.048551) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.2, 'vect__ngram_range': (1, 1)}
# 0.783151 (0.020655) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.2, 'vect__ngram_range': (1, 2)}
# 0.768865 (0.024460) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.2, 'vect__ngram_range': (1, 3)}
# 0.770314 (0.028458) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 1)}
# 0.777437 (0.031581) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 2)}
# 0.778855 (0.038759) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 3)}
# 0.778845 (0.027767) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 1)}
# 0.771712 (0.040861) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 2)}
# 0.780284 (0.037245) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 3)}
# 0.781722 (0.021163) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 1)}
# 0.780284 (0.044715) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 2)}
# 0.777427 (0.042869) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 3)}
# 0.768886 (0.030280) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 1)}
# 0.766028 (0.047341) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 2)}
# 0.775998 (0.051763) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 3)}
# 0.706140 (0.025232) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.1, 'vect__ngram_range': (1, 1)}
# 0.777497 (0.015307) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.1, 'vect__ngram_range': (1, 2)}
# 0.801763 (0.022680) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.1, 'vect__ngram_range': (1, 3)}
# 0.717548 (0.032109) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.2, 'vect__ngram_range': (1, 1)}
# 0.743283 (0.043624) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.2, 'vect__ngram_range': (1, 2)}
# 0.756120 (0.039843) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.2, 'vect__ngram_range': (1, 3)}
# 0.706099 (0.021329) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 1)}
# 0.743191 (0.024212) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 2)}
# 0.756028 (0.015066) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 3)}
# 0.706109 (0.028585) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 1)}
# 0.730365 (0.031586) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 2)}
# 0.764630 (0.008786) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 3)}
# 0.690385 (0.033223) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 1)}
# 0.717528 (0.030325) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 2)}
# 0.748896 (0.015745) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 3)}
# 0.674732 (0.039159) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 1)}
# 0.716109 (0.026206) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 2)}
# 0.737467 (0.026538) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 3)}
# 0.523526 (0.006165) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.1, 'vect__ngram_range': (1, 1)}
# 0.517832 (0.003195) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.1, 'vect__ngram_range': (1, 2)}
# 0.517832 (0.003195) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.1, 'vect__ngram_range': (1, 3)}
# 0.522097 (0.005635) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.2, 'vect__ngram_range': (1, 1)}
# 0.517832 (0.003195) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.2, 'vect__ngram_range': (1, 2)}
# 0.517832 (0.003195) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.2, 'vect__ngram_range': (1, 3)}
# 0.529240 (0.007938) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 1)}
# 0.517832 (0.003195) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 2)}
# 0.517832 (0.003195) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 3)}
# 0.530669 (0.008323) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 1)}
# 0.519260 (0.002870) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 2)}
# 0.517832 (0.003195) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 3)}
# 0.530669 (0.009470) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 1)}
# 0.520689 (0.004754) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 2)}
# 0.517832 (0.003195) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 3)}
# 0.530648 (0.009367) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 1)}
# 0.523546 (0.007712) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 2)}
# 0.517832 (0.005533) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 3)}
# 0.706059 (0.038108) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.1, 'vect__ngram_range': (1, 1)}
# 0.583364 (0.038764) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.1, 'vect__ngram_range': (1, 2)}
# 0.536363 (0.013199) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.1, 'vect__ngram_range': (1, 3)}
# 0.750304 (0.045194) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.2, 'vect__ngram_range': (1, 1)}
# 0.686018 (0.068511) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.2, 'vect__ngram_range': (1, 2)}
# 0.597649 (0.043076) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.2, 'vect__ngram_range': (1, 3)}
# 0.780253 (0.028009) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 1)}
# 0.760243 (0.048707) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 2)}
# 0.691702 (0.075932) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 3)}
# 0.778815 (0.030373) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 1)}
# 0.763110 (0.050883) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 2)}
# 0.717406 (0.073557) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 3)}
# 0.778804 (0.035662) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 1)}
# 0.748835 (0.050124) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 2)}
# 0.703141 (0.073027) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 3)}
# 0.767396 (0.040898) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 1)}
# 0.751692 (0.040667) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 2)}
# 0.694610 (0.055855) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 3)}
# 0.757467 (0.025744) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.1, 'vect__ngram_range': (1, 1)}
# 0.723171 (0.040692) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.1, 'vect__ngram_range': (1, 2)}
# 0.677558 (0.026594) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.1, 'vect__ngram_range': (1, 3)}
# 0.760324 (0.019683) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.2, 'vect__ngram_range': (1, 1)}
# 0.763110 (0.034954) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.2, 'vect__ngram_range': (1, 2)}
# 0.737427 (0.038109) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.2, 'vect__ngram_range': (1, 3)}
# 0.795917 (0.034942) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 1)}
# 0.774498 (0.041450) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 2)}
# 0.765988 (0.034854) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 3)}
# 0.784559 (0.024339) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 1)}
# 0.790243 (0.029113) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 2)}
# 0.785988 (0.024155) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 3)}
# 0.771722 (0.021492) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 1)}
# 0.780243 (0.037134) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 2)}
# 0.780253 (0.034829) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 3)}
# 0.753171 (0.018850) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 1)}
# 0.780243 (0.037408) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 2)}
# 0.773100 (0.032179) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 3)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'poly', 'vect__max_df': 0.1, 'vect__ngram_range': (1, 1)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'poly', 'vect__max_df': 0.1, 'vect__ngram_range': (1, 2)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'poly', 'vect__max_df': 0.1, 'vect__ngram_range': (1, 3)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'poly', 'vect__max_df': 0.2, 'vect__ngram_range': (1, 1)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'poly', 'vect__max_df': 0.2, 'vect__ngram_range': (1, 2)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'poly', 'vect__max_df': 0.2, 'vect__ngram_range': (1, 3)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'poly', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 1)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'poly', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 2)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'poly', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 3)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'poly', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 1)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'poly', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 2)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'poly', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 3)}
# 0.519260 (0.005352) with: {'SVM__C': 0.1, 'SVM__kernel': 'poly', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 1)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'poly', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 2)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'poly', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 3)}
# 0.519260 (0.008334) with: {'SVM__C': 0.1, 'SVM__kernel': 'poly', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 1)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'poly', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 2)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'poly', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 3)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'rbf', 'vect__max_df': 0.1, 'vect__ngram_range': (1, 1)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'rbf', 'vect__max_df': 0.1, 'vect__ngram_range': (1, 2)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'rbf', 'vect__max_df': 0.1, 'vect__ngram_range': (1, 3)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'rbf', 'vect__max_df': 0.2, 'vect__ngram_range': (1, 1)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'rbf', 'vect__max_df': 0.2, 'vect__ngram_range': (1, 2)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'rbf', 'vect__max_df': 0.2, 'vect__ngram_range': (1, 3)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'rbf', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 1)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'rbf', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 2)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'rbf', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 3)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'rbf', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 1)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'rbf', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 2)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'rbf', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 3)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'rbf', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 1)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'rbf', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 2)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'rbf', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 3)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'rbf', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 1)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'rbf', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 2)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'rbf', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 3)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.1, 'vect__ngram_range': (1, 1)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.1, 'vect__ngram_range': (1, 2)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.1, 'vect__ngram_range': (1, 3)}
# 0.517832 (0.005533) with: {'SVM__C': 0.1, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.2, 'vect__ngram_range': (1, 1)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.2, 'vect__ngram_range': (1, 2)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.2, 'vect__ngram_range': (1, 3)}
# 0.519260 (0.005352) with: {'SVM__C': 0.1, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 1)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 2)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 3)}
# 0.519260 (0.005352) with: {'SVM__C': 0.1, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 1)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 2)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 3)}
# 0.519260 (0.005352) with: {'SVM__C': 0.1, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 1)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 2)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 3)}
# 0.519260 (0.005352) with: {'SVM__C': 0.1, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 1)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 2)}
# 0.517832 (0.003195) with: {'SVM__C': 0.1, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 3)}

# %%
count_vect = CountVectorizer(ngram_range=(1,2), max_df=0.5).fit(df['Processed_Reviews'].values.astype('U'))

bow_train = count_vect.transform(X_train.values.astype('U'))
bow_test = count_vect.transform(X_test.values.astype('U'))
SVM_optimized = SVC(C= 50,kernel='rbf')

# %%
# fit the model with pre-processed data
SVM_optimized.fit(bow_train, y_train)

#perform classification and prediction on samples in tf_test
predicted_SVM2 = SVM_optimized.predict(bow_test)
print(classification_report(y_test, predicted_SVM2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.87      0.88      5035
#            1       0.87      0.90      0.89      4965
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000

# %%
joblib.dump(SVM_optimized, 'saved_model_SVMOpt.pkl')
# Out:
# ['saved_model_SVMOpt.pkl']

# %%
count_vect = CountVectorizer(ngram_range=(1,2), max_df=0.5).fit(df['Processed_Reviews'].values.astype('U'))

bow_train = count_vect.transform(X_train.values.astype('U'))
bow_test = count_vect.transform(X_test.values.astype('U'))
SVM_optimized2 = SVC(C= 50,kernel='sigmoid')

# %%
# fit the model with pre-processed data
SVM_optimized2.fit(bow_train, y_train)

#perform classification and prediction on samples in tf_test
predicted_SVM2 = SVM_optimized2.predict(bow_test)
print(classification_report(y_test, predicted_SVM2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.77      0.77      5035
#            1       0.76      0.77      0.77      4965
#
#     accuracy                           0.77     10000
#    macro avg       0.77      0.77      0.77     10000
# weighted avg       0.77      0.77      0.77     10000

# %%
joblib.dump(SVM_optimized2, 'saved_model_SVMOpt2.pkl')
# Out:
# ['saved_model_SVMOpt2.pkl']

# %%
count_vect = CountVectorizer(ngram_range=(1,3), max_df=0.2).fit(df['Processed_Reviews'].values.astype('U'))
bow_train = count_vect.transform(X_train.values.astype('U'))
bow_test = count_vect.transform(X_test.values.astype('U'))

SVM_optimized3 = SVC(C= 50,kernel='rbf')

# %%
SVM_optimized3.fit(bow_train, y_train)

#perform classification and prediction on samples in tf_test
predicted_SVM3 = SVM_optimized3.predict(bow_test)
print(classification_report(y_test, predicted_SVM3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.85      0.88      5035
#            1       0.86      0.91      0.88      4965
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000

# %%
print(classification_report(y_test, predicted_SVM3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.85      0.88      5035
#            1       0.86      0.91      0.88      4965
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000

# %%
joblib.dump(SVM_optimized3, 'saved_model_SVMOpt3.pkl')
# Out:
# ['saved_model_SVMOpt3.pkl']

# %%
count_vect = CountVectorizer(ngram_range=(1,3), max_df=0.4).fit(df['Processed_Reviews'].values.astype('U'))
bow_train = count_vect.transform(X_train.values.astype('U'))
bow_test = count_vect.transform(X_test.values.astype('U'))

SVM_optimized4 = SVC(C= 1,kernel='sigmoid')

# %%
SVM_optimized4.fit(bow_train, y_train)

#perform classification and prediction on samples in tf_test
predicted_SVM4 = SVM_optimized4.predict(bow_test)
print(classification_report(y_test, predicted_SVM4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87      5035
#            1       0.87      0.88      0.87      4965
#
#     accuracy                           0.87     10000
#    macro avg       0.87      0.87      0.87     10000
# weighted avg       0.87      0.87      0.87     10000

# %%
joblib.dump(SVM_optimized4, 'saved_model_SVMOpt4.pkl')
# Out:
# ['saved_model_SVMOpt4.pkl']

# %% [markdown]
# ## Load models

# %%
svm = joblib.load('saved_model.pkl')
#rna = joblib.load('LSTM.pkl')
svmMorOpt = joblib.load('saved_model_SVMOpt.pkl')
svmOpt = joblib.load('saved_model_SVMOpt2.pkl')
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator SVC from version 1.2.2 when using version 1.1.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
test_1 = ['I would highly recommend this movie to anyone. Its a must-watch!']
test_1 = count_vect.transform(test_1).toarray()


#Printing prediction

print(SVM.predict(test_1))
#print(SVM.predict(test_1))
# Out:
# [1]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7a5b1e8f-5fb8-49ad-8f36-77068147d699' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
